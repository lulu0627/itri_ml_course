# %% [markdown]
# <a href="https://colab.research.google.com/github/lulu0627/itri_ml_course/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv('train.csv')
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   NaN         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
df=pd.read_csv('train.csv')
df.iloc[500:601]
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 500          501         0       3  ...   8.6625   NaN         S
# 501          502         0       3  ...   7.7500   NaN         Q
# 502          503         0       3  ...   7.6292   NaN         Q
# 503          504         0       3  ...   9.5875   NaN         S
# 504          505         1       1  ...  86.5000   B79         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 596          597         1       2  ...  33.0000   NaN         S
# 597          598         0       3  ...   0.0000   NaN         S
# 598          599         0       3  ...   7.2250   NaN         C
# 599          600         1       1  ...  56.9292   A20         C
# 600          601         1       2  ...  27.0000   NaN         S
#
# [101 rows x 12 columns]

# %% [markdown]
# # New Section

# %%
df=pd.read_csv('train.csv')
df.loc[0:891, ['Sex','Age','Survived','Embarked']]
# Out:
#         Sex   Age  Survived Embarked
# 0      male  22.0         0        S
# 1    female  38.0         1        C
# 2    female  26.0         1        S
# 3    female  35.0         1        S
# 4      male  35.0         0        S
# ..      ...   ...       ...      ...
# 886    male  27.0         0        S
# 887  female  19.0         1        S
# 888  female   NaN         0        S
# 889    male  26.0         1        C
# 890    male  32.0         0        Q
#
# [891 rows x 4 columns]

# %%
df.loc[0:891, ['Sex','Age','Survived','Embarked']].mode()
# Out:
#     Sex   Age  Survived Embarked
# 0  male  24.0         0        S

# %%
df.loc[0:891, ['Sex','Age','Survived','Embarked']].mean()
# Out:
# Age         29.699118
# Survived     0.383838
# dtype: float64

# %%
ax1 = df.plot.scatter(x='Age',
                      y='Survived',
                      c='DarkBlue')

# %%
ax = df.plot.bar(x='Age', y='Survived', rot=0)

# %% [markdown]
# # New Section
